# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

from pygentoolbox.DicerSignal import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-06-24 15:26:20.546515

# %%
filelist_f = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_EV_L_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_KD_L_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_EV_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
             ]
filelist_r = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_EV_L_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_KD_L_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_EV_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_KD_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.R.Ptiwi08RIPLateSRCsClass1.Only.sort.sam', \
              ]


seqlength=23
maxdepth=0

main(filelist_f, filelist_r, seqlength, maxdepth)
# Out:
# ##################################################
# Count forward and reverse reads
# Working on: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam
# Output file of 5' and 3' counts: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.tsv
#
# Working on: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam
# Output file of 5' and 3' counts: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.tsv
#
# Working on: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.sam
# Output file of 5' and 3' counts: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.tsv
#
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

from pygentoolbox.DicerSignalMakePlots import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-06-30 10:04:07.401110

# %%
pingpongfile = '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.out'
dicersignalfiles = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_EV_L_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_KD_L_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_EV_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_KD_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out'\
                   ]
bamfiles = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_EV_L_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_KD_L_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_EV_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_KD_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.sort.bam'\
            ]
rowtitles = ['P08RIP_L', \
             'P08RIP_L+', \
             'P08_KD', \
             'Hen1_EV', \
             'Hen1_KD', \
             'Dcr1_EV', \
             'Dcr1_KD', \
             'SM.HQ', \
             'SM.DN'
            ]
bedfile = '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08RIP_Late_SRCs_Class1.bed'
maxy = False

main(pingpongfile, dicersignalfiles, bamfiles, rowtitles, bedfile, maxy)
# Out:
# Total reads inside bed features: 1561129 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 1243806 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 657608 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08_KD_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 1384755 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_EV_L_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 1160139 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Hen1_KD_L_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 783641 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_EV_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 110425 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/Dcr1_KD_23bp.trim.Pt_51_Mac.sort.bam
# ...

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

from pygentoolbox.DicerSignalMakePlots import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-07-01 14:58:50.562619

# %%
pingpongfile = '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.out'
dicersignalfiles = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
                    '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.F.Ptiwi08RIPLateSRCsClass1.Only.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out'\
                   ]
bamfiles = ['/media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.sort.bam', \
            '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.sort.bam'\
            ]
rowtitles = ['P08RIP_L', \
             'P08RIP_L+', \
             'SM.HQ', \
             'SM.DN'
            ]
bedfile = '/media/sf_LinuxShare/Projects/Theresa/DicerSignals/Ptiwi08RIP_Late_SRCs_Class1.bed'
figsizex = 10  
figsizey = 4.44
maxy = True

main(pingpongfile, dicersignalfiles, bamfiles, rowtitles, bedfile, figsizex, figsizey, maxy)
# Out:
# Total reads inside bed features: 1561129 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/52_Late_R1_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 1243806 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/53_Later_R1_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 10445775 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.HQ_ASBK7_23bp.trim.Pt_51_Mac.sort.bam
# Total reads inside bed features: 9831609 for file: /media/sf_LinuxShare/Projects/Theresa/DicerSignals/SM.DN_ASBK8_23bp.trim.Pt_51_Mac.sort.bam

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
print(datetime.datetime.now())

from pygentoolbox.SummarizePingPongSignal import main
#dir(pygentoolbox.Tools)
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
pingpongfiles = ['/media/sf_LinuxShare/Projects/Theresa/Hisat2/FlagHA_Pt08/Pt_51_Mac/Ptiwi08RIP_Late_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/FlagHA_Pt08/Pt_51_Mac/Ptiwi08RIP_Later_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/EV_Total_sRNA/Late/Pt_51_Mac/fastp/hisat2/TotalsRNA_EV_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Pt08KD_TotalsRNA/Pt_51_Mac/TotalsRNA_Ptiwi08KD_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Dcr1_KD/Pt_51_Mac/EV/fastp/hisat2/Dcr1_EV_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Dcr1_KD/Pt_51_Mac/KD/fastp/hisat2/Dcr1_KD_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Slicer_Mutants_HQ_DN/Pt_51_Mac/Ptiwi08_SM.HQ_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out', \
              '/media/sf_LinuxShare/Projects/Theresa/Hisat2/Slicer_Mutants_HQ_DN/Pt_51_Mac/Ptiwi08_SM.DN_23bp.F.sort.53.PingPong.FvsR.55.DicerSignal.SortPosition.out'\
             ]
bedfile = '/media/sf_LinuxShare/Projects/Theresa/Hisat2/FlagHA_Pt08/Pt_51_Mac/RefinedPtiwi08sRNACoordinates2.bed'

main(pingpongfiles, bedfile)
